# %% [markdown]
# <a href="https://colab.research.google.com/github/coldDayss/SNS_BigData/blob/main/%EB%84%A4%EC%9D%B4%EB%B2%84_%EC%98%81%ED%99%94_%EB%A6%AC%EB%B7%B0_%EB%B0%8F_%ED%8F%89%EC%A0%90_%EC%88%98%EC%A7%91%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
from selenium import webdriver

import time
import sys
import re
import math
import numpy  
import pandas as pd 
import os
import random

query_txt = input('    1.크롤링 할 영화의 제목을 입력하세요: ')
query_url = 'https://movie.naver.com'

cnt = int(input('    2.크롤링 할 리뷰건수는 몇건입니까?: '))
page_cnt = math.ceil(cnt / 10)

f_dir = input("    3.파일을 저장할 폴더명만 쓰세요(예:  /Users/charli/Temp/test_data  ):")
print("-" *80)
print("데이터 수집중 입니다")

#현재 시간을 저장하는 파일 이름에 넣는다.
now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)
os.makedirs(f_dir+s+'-'+query_txt)
os.chdir(f_dir+s+'-'+query_txt)

ff_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.txt'
fc_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.csv'
fx_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.xls'


s_time = time.time( )
path = "/Users/charli/Temp/chromedriver"
driver = webdriver.Chrome(path)

driver.get(query_url)
time.sleep(3)

# 영화 제목으로 검색창에 검색을 한다.
element = driver.find_element_by_id("ipt_tx_srch")
element.send_keys(query_txt)
driver.find_element_by_xpath("""//*[@id="jSearchArea"]/div/button""").click()
driver.find_element_by_xpath("""//*[@id="old_content"]/ul[2]/li/dl/dt/a""").click()

driver.find_element_by_link_text("평점").click()
driver.switch_to.frame('pointAfterListIframe')

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
result= soup.find('div', class_='score_total').find('strong','total').find_all('em')
result2 = result[0].get_text()

print("=" *80)
result3 = result2.replace(",","")
result4 = re.search("\d+",result3)
search_cnt = int(result4.group())

if cnt > search_cnt :
    cnt = search_cnt

print("전체 검색 결과 건수 :",search_cnt,"건")
print("실제 최종 출력 건수",cnt)

print("\n")
page_cnt = math.ceil(cnt / 10)
print("크롤링 할 총 페이지 번호: ",page_cnt)
print("=" *80)


score2=[]
review2=[]
writer2=[]
wdate2=[]
gogam2=[]
g_gogam2=[]
b_gogam2=[]
dwlist2=[]

count = 0       
click_count = 1 

while ( click_count <= page_cnt )  :
            
            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            
            score_result = soup.find('div', class_='score_result').find('ul')
            slist = score_result.find_all('li')

            for li in slist:

                count += 1
                
                f = open(ff_name, 'a',encoding='UTF-8')
            
                print("\n")
                print("총 %s 건 중 %s 번째 리뷰 데이터를 수집합니다==================" %(cnt,count))
                score = li.find('div', class_='star_score').find('em').get_text()
                print("1.별점:","*"*int(score),": ", score)
                score2.append(score)
                f.write("\n")
                f.write("총 %s 건 중 %s 번째 리뷰 데이터를 수집합니다==================" %(cnt,count) + "\n")
                f.write("1.별점:"+score + "\n")
            
                review = li.find('div', class_='score_reple').find('p').get_text()
                print("2.리뷰내용:",review)
                f.write("2.리뷰내용:" + review + "\n")
                review2.append(review)
         
                dwlist = li.find('div',class_='score_reple').find_all('em')
                writer = dwlist[0].find('span').get_text()
                print("3.작성자:",writer)
                f.write("3.작성자:" + writer + "\n")
                writer2.append(writer)
                
                wdate = dwlist[1].text
                print('4.작성일자:',wdate)
                f.write("4.작성일자:" + wdate + "\n")
                wdate2.append(wdate)
            
                gogam = li.find('div', class_='btn_area').find_all('strong')
                g_gogam = gogam[0].text
                print('5.공감:',g_gogam)
                f.write("5.공감:" + g_gogam + "\n")
                g_gogam2.append(g_gogam)
                
                b_gogam = gogam[1].text
                print('6.비공감:', b_gogam)
                f.write("6.비공감:" + b_gogam + "\n")
                b_gogam2.append(b_gogam)
                print("\n")

                

                if count == cnt :
                    break
            
            time.sleep(random.randrange(1,2))  

            click_count += 1
            
            if click_count > page_cnt :
                break
            else :
                driver.find_element_by_link_text("%s" %click_count).click()

            time.sleep(random.randrange(1,2))


#xls 형태와 csv 형태로 저장한다.
naver_movie = pd.DataFrame()
naver_movie['별점(평점)']=score2
naver_movie['리뷰내용']=review2
naver_movie['작성자']=writer2
naver_movie['작성일자']=wdate2
naver_movie['공감횟수']=g_gogam2
naver_movie['비공감횟수']=b_gogam2

naver_movie.to_csv(fc_name,encoding="utf-8-sig",index=True)
naver_movie.to_excel(fx_name ,index=True)

e_time = time.time( )
t_time = e_time - s_time


print("\n") 
print("=" *80)
print("1.요청된 총 %s 건의 리뷰 중에서 실제 크롤링 된 리뷰수는 %s 건입니다" %(cnt,count))
print("2.총 소요시간은 %s 초 입니다 " %round(t_time,1))
print("3.파일 저장 완료: txt 파일명 : %s " %ff_name)
print("4.파일 저장 완료: csv 파일명 : %s " %fc_name)
print("5.파일 저장 완료: xls 파일명 : %s " %fx_name)
print("=" *80)

driver.close( )
# Out:
#     1.크롤링 할 영화의 제목을 입력하세요: 분노의 질주
#     2.크롤링 할 리뷰건수는 몇건입니까?: 30
#     3.파일을 저장할 폴더명만 쓰세요(예:  /Users/charli/Temp/test_data  ):/Users/charli/Temp/test_data
# --------------------------------------------------------------------------------
# 데이터 수집중 입니다
# ================================================================================
# 전체 검색 결과 건수 : 5244 건
# 실제 최종 출력 건수 30
#
#
# 크롤링 할 총 페이지 번호:  3
# ================================================================================
#
#
# 총 30 건 중 1 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																뇌를 비우고 즐기면 된다
#
#
#
#
#
# 3.작성자: 테드(gado****)
# 4.작성일자: 2021.05.19 13:06
# 5.공감: 1232
# 6.비공감: 118
#
#
#
#
# 총 30 건 중 2 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																시리즈 팬들에게 주는 선물 같았던 엔딩..크.... 아련아련 ㅜㅜ
#
#
#
#
#
# 3.작성자: 됴롱(gusr****)
# 4.작성일자: 2021.05.19 10:45
# 5.공감: 753
# 6.비공감: 79
#
#
#
#
# 총 30 건 중 3 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																역시 분노의 질주! 이런 블록버스터는 역시 극장에서 봐야지
#
#
#
#
#
# 3.작성자: high****
# 4.작성일자: 2021.05.19 10:43
# 5.공감: 697
# 6.비공감: 104
#
#
#
#
# 총 30 건 중 4 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																와 오랜만에 극장에서 봤는데 스케일 도랐 액션 개쩜
#
#
#
#
#
# 3.작성자: 로다쥬(yj05****)
# 4.작성일자: 2021.05.19 10:47
# 5.공감: 642
# 6.비공감: 93
#
#
#
#
# 총 30 건 중 5 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																티라노사우루스는 팔이 짧아 분노의 질주 꿀잼 액션을 보고도 박수를 못쳐서 멸종됐다.
#
#
#
#
#
# 3.작성자: gmlw****
# 4.작성일자: 2021.05.19 10:47
# 5.공감: 719
# 6.비공감: 180
#
#
#
#
# 총 30 건 중 6 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
# 스포일러가 포함된 감상평입니다. 감상평 보기
#
#
#
#
# 																전작까지는 우주빼고 안가본데가 없었는데 이제 우주까지 나가네요..
#
#
#
#
#
# 3.작성자: Song UG(song****)
# 4.작성일자: 2021.05.19 12:22
# 5.공감: 572
# 6.비공감: 55
#
#
#
#
# 총 30 건 중 7 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																졸라 신난다 진짜ㅋㅋㅋ 아 아침 일찍 보고 왔는데 보람있군
#
#
#
#
#
# 3.작성자: 강은정(zer5****)
# 4.작성일자: 2021.05.19 12:05
# 5.공감: 557
# 6.비공감: 67
#
#
#
#
# 총 30 건 중 8 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																저스틴 린 감독이 진짜 오리지널 감독이긴 하네. 진짜 <분노의 질주> 시리즈 보는 것 같음!!!!
#
#
#
#
#
# 3.작성자: Hailey(hyel****)
# 4.작성일자: 2021.05.19 10:46
# 5.공감: 514
# 6.비공감: 64
#
#
#
#
# 총 30 건 중 9 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																진짜 상상이상의 액션ㅋㅋㅋㅋ 아직 안본 분들 정말 상상도 못하셨을 겁니다
#
#
#
#
#
# 3.작성자: 고니(lepa****)
# 4.작성일자: 2021.05.19 12:54
# 5.공감: 486
# 6.비공감: 55
#
#
#
#
# 총 30 건 중 10 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																너무 재미있었어요~~ 기다린 보람이 있었어요 다음편두 더 기대할게요
#
#
#
#
#
# 3.작성자: 문종칠(whdc****)
# 4.작성일자: 2021.05.19 11:12
# 5.공감: 440
# 6.비공감: 54
#
#
#
#
# 총 30 건 중 11 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ******** :  8
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																마지막 닛산 스카이 라인이 나오는 장면 만으로도 이 영화는 가치가 있다
#
#
#
#
#
# 3.작성자: 천재소년98(mond****)
# 4.작성일자: 2021.05.19 14:22
# 5.공감: 350
# 6.비공감: 15
#
#
#
#
# 총 30 건 중 12 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
#
#
#
#
#
# 																CGV 수원 조조 6시30분 전 세계 최초 관람하고 댓 남깁니다 와 이번꺼 액션 장난 아님 무조건 극장에서 봐야함 빡빡이 2명이 빠져서 아쉽지만 그래도 다른 배우들이 한 몫했음 쿠키도 있으니 챙겨보길 바람
#
#
#
#
#
# 3.작성자: Abc123(fowe****)
# 4.작성일자: 2021.05.19 09:12
# 5.공감: 352
# 6.비공감: 22
#
#
#
#
# 총 30 건 중 13 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																빈 디젤은 세월이 이렇게 많이 흘렀는데도 전혀 나이 먹지 않은 느낌이다.. 진짜 멋짐bb
#
#
#
#
#
# 3.작성자: 이영람(rsls****)
# 4.작성일자: 2021.05.19 23:34
# 5.공감: 334
# 6.비공감: 10
#
#
#
#
# 총 30 건 중 14 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
#
#
#
#
#
# 																흐엉...ㅠㅠ 너무 그리웠고 너무 반가웠어요!극장 자리에 딱 앉았을 때의 기분을 얼마나 느끼고 싶었었는지..! 휴 포스터 들고 코로나 병맥 사 들고 집에 갑니다.
#
#
#
#
#
# 3.작성자: hell****
# 4.작성일자: 2021.05.19 09:49
# 5.공감: 335
# 6.비공감: 13
#
#
#
#
# 총 30 건 중 15 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																분노의질주 시리즈는 무조건 극장에서 봐야 함
#
#
#
#
#
# 3.작성자: 양다일 사랑해(ma3y****)
# 4.작성일자: 2021.05.19 13:58
# 5.공감: 330
# 6.비공감: 12
#
#
#
#
# 총 30 건 중 16 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
#
#
#
#
#
# 																역시는 역시다! 이런 블록버스터를 극장에서 본게 얼마만이냐 대체 ㅎㅎㅎ
#
#
#
#
#
# 3.작성자: jydo****
# 4.작성일자: 2021.05.19 09:19
# 5.공감: 328
# 6.비공감: 11
#
#
#
#
# 총 30 건 중 17 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																역시 분노의 질주! 엄청난 스케일과 함께 좋은 노래들이 많아서 잘 봤습니다! 마지막 쿠키영상까지 짱이었습니다!
#
#
#
#
#
# 3.작성자: 다인(myda****)
# 4.작성일자: 2021.05.19 16:30
# 5.공감: 329
# 6.비공감: 12
#
#
#
#
# 총 30 건 중 18 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																분노의질주는 역시 짱이네요 신나는 액션으로 너무 재밌게 보고 왔습니다
#
#
#
#
#
# 3.작성자: 송유선(h2ts****)
# 4.작성일자: 2021.05.19 12:44
# 5.공감: 326
# 6.비공감: 13
#
#
#
#
# 총 30 건 중 19 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																화끈하네요 시간가는줄 몰랐어요멋지네
#
#
#
#
#
# 3.작성자: 호반장(ljhg****)
# 4.작성일자: 2021.05.19 16:44
# 5.공감: 324
# 6.비공감: 12
#
#
#
#
# 총 30 건 중 20 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
#
#
#
#
#
# 																그냥 최고임 다시 봐야지
#
#
#
#
#
# 3.작성자: 김현제(hyun****)
# 4.작성일자: 2021.05.19 09:20
# 5.공감: 322
# 6.비공감: 11
#
#
#
#
# 총 30 건 중 21 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																8이 액션씬이 더 좋았지만 9도 진짜 스토리랑 연출면에거 나무랄게 없었다. 다음 시리즈에는 드웨인 존슨도 참여했으면 좋겠다. 역시 최고의 영화
#
#
#
#
#
# 3.작성자: 공명(nyj3****)
# 4.작성일자: 2021.05.19 14:24
# 5.공감: 325
# 6.비공감: 14
#
#
#
#
# 총 30 건 중 22 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																토레로~~~정말멋잇어
#
#
#
#
#
# 3.작성자: hong8956(ghdw****)
# 4.작성일자: 2021.05.19 17:47
# 5.공감: 317
# 6.비공감: 7
#
#
#
#
# 총 30 건 중 23 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																스케일 짱이네요ㄷㄷ 오랜만에 잼있게봤어요
#
#
#
#
#
# 3.작성자: 리에(seon****)
# 4.작성일자: 2021.05.19 12:53
# 5.공감: 320
# 6.비공감: 10
#
#
#
#
# 총 30 건 중 24 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********* :  9
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																액션은 그대로, 하나되는 가족
#
#
#
#
#
# 3.작성자: 유포니움(ki8k****)
# 4.작성일자: 2021.05.19 12:54
# 5.공감: 322
# 6.비공감: 13
#
#
#
#
# 총 30 건 중 25 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
#
#
#
#
#
# 																이 영화를 훗날 집에서 본 사람은 이 영화를 보았다고 말할 자격이 없다.
#
#
#
#
#
# 3.작성자: fink****
# 4.작성일자: 2021.05.19 11:08
# 5.공감: 313
# 6.비공감: 5
#
#
#
#
# 총 30 건 중 26 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
#
#
#
#
#
# 																러닝타임이 좀 길어서 놀랬긴 한데 액션은~ 돈이 퐝퐝터짐. 대리만족 쩔고 한 한이 나와요! 갈수록 송강호 배우랑 닮아보이는데 쨌든 재밌음.
#
#
#
#
#
# 3.작성자: daka****
# 4.작성일자: 2021.05.19 10:43
# 5.공감: 313
# 6.비공감: 5
#
#
#
#
# 총 30 건 중 27 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
#
#
#
#
#
# 																영화가 재밌어요
#
#
#
#
#
# 3.작성자: 최민완(choi****)
# 4.작성일자: 2021.05.19 09:39
# 5.공감: 316
# 6.비공감: 8
#
#
#
#
# 총 30 건 중 28 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																분노의 질주는 실망이란 단어는 없다
#
#
#
#
#
# 3.작성자: 뽁서(jmk8****)
# 4.작성일자: 2021.05.19 14:26
# 5.공감: 322
# 6.비공감: 14
#
#
#
#
# 총 30 건 중 29 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																박진감 넘치는 액션 짱~^^ 오랜만의 영화관 나들이 자체가 힐링이네요
#
#
#
#
#
# 3.작성자: 까르꼬(trem****)
# 4.작성일자: 2021.05.19 13:43
# 5.공감: 322
# 6.비공감: 15
#
#
#
#
# 총 30 건 중 30 번째 리뷰 데이터를 수집합니다==================
# 1.별점: ********** :  10
# 2.리뷰내용:
# 관람객
#
#
#
#
#
# 																말이 필요없다.. 걍 두시간 넘는 시간이 후딱 지나 가더라.. 이런게 바로 시간 순삭ㅋㅋㅋ
#
#
#
#
#
# 3.작성자: 진주목걸이(yals****)
# 4.작성일자: 2021.05.19 13:59
# 5.공감: 329
# 6.비공감: 25
# ================================================================================
# 1.요청된 총 30 건의 리뷰 중에서 실제 크롤링 된 리뷰수는 30 건입니다
# 2.총 소요시간은 19.8 초 입니다
# 3.파일 저장 완료: txt 파일명 : /Users/charli/Temp/test_data2021-06-12-16-20-31-분노의 질주\2021-06-12-16-20-31-분노의 질주.txt
# 4.파일 저장 완료: csv 파일명 : /Users/charli/Temp/test_data2021-06-12-16-20-31-분노의 질주\2021-06-12-16-20-31-분노의 질주.csv
# 5.파일 저장 완료: xls 파일명 : /Users/charli/Temp/test_data2021-06-12-16-20-31-분노의 질주\2021-06-12-16-20-31-분노의 질주.xls
# ================================================================================
